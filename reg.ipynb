# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pylab as pl

# %%
data=pd.read_csv(r"C:\programming languages\AI ML\student-mat.csv")

data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
data.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %%
data.drop(['school'],inplace=True,axis=1)
data.drop(['address'],inplace=True,axis=1)
data.drop(['Mjob'],inplace=True,axis=1)
data.drop(['Fjob'],inplace=True,axis=1)
data.drop(['reason'],inplace=True,axis=1)

# %%
#sns.pairplot(data=data)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(), square = True, annot=True, linewidth=0.5)
plt.show()

# %%
#data.drop(['studytime'],inplace=True,axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 28 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         395 non-null    object
#  1   age         395 non-null    int64
#  2   famsize     395 non-null    object
#  3   Pstatus     395 non-null    object
#  4   Medu        395 non-null    int64
#  5   Fedu        395 non-null    int64
#  6   guardian    395 non-null    object
#  7   traveltime  395 non-null    int64
#  8   studytime   395 non-null    int64
#  9   failures    395 non-null    int64
#  10  schoolsup   395 non-null    object
#  11  famsup      395 non-null    object
#  12  paid        395 non-null    object
#  13  activities  395 non-null    object
#  14  nursery     395 non-null    object
#  15  higher      395 non-null    object
#  16  internet    395 non-null    object
#  17  romantic    395 non-null    object
#  18  famrel      395 non-null    int64
# ...

# %%
op=pd.get_dummies(data['paid'])
data=pd.concat([data,op],axis=1)

# %%
ap=pd.get_dummies(data['sex'])
data=pd.concat([data,ap],axis=1)

# %%
rm=pd.get_dummies(data['romantic'])
data=pd.concat([data,rm],axis=1)

# %%
ny=pd.get_dummies(data['nursery'])
data=pd.concat([data,ny],axis=1)

# %%
hi=pd.get_dummies(data['higher'])
data=pd.concat([data,hi],axis=1)

# %%
inte=pd.get_dummies(data['internet'])
data=pd.concat([data,inte],axis=1)

# %%
sc=pd.get_dummies(data['schoolsup'])
data=pd.concat([data,sc],axis=1)

# %%
fa=pd.get_dummies(data['famsup'])
data=pd.concat([data,fa],axis=1)

# %%
f=pd.get_dummies(data['famsize'])
data=pd.concat([data,f],axis=1)

# %%
ps=pd.get_dummies(data['Pstatus'])
data=pd.concat([data,ps],axis=1)

# %%
data.drop(['paid','romantic','activities','nursery','higher','internet','schoolsup','famsup','sex','famsize','Pstatus','guardian'],
          inplace=True,axis=1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x=data.drop(['G1','G2','G3'],axis=1)
y=data[['G1','G2','G3']]
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([[ 4.56365902,  5.40820731,  3.66365019],
#        [ 9.12855554,  8.52952702,  7.59660048],
#        [10.9300757 ,  9.58347006,  8.74088658],
#        [11.3492348 , 12.10069992, 12.2485587 ],
#        [ 8.91276266,  8.83003431,  8.47224309],
#        [10.71853939, 10.85864584,  9.86184999],
#        [12.09517903, 11.5397945 , 11.53439964],
#        [12.22795642, 12.05856101, 12.74058786],
#        [10.49318486, 10.583923  , 10.39621583],
#        [12.24437226, 10.98452928, 11.27435469],
#        [13.19400833, 13.34963309, 13.42795922],
#        [12.99145606, 11.88619328, 11.48084915],
#        [11.27958116, 10.98712837, 10.60819912],
#        [12.96996381, 12.42371814, 12.243618  ],
#        [11.21872215, 10.96691431, 11.33737581],
#        [10.1775469 , 11.22095281, 11.59953349],
#        [11.45300622, 11.03665058, 10.56256874],
#        [10.72179792,  9.93679542, 10.00043771],
#        [12.42090248, 11.65132193, 10.40618982],
#        [12.67449685, 10.63120789, 10.37990317],
# ...

# %%
y_test
# Out:
#      G1  G2  G3
# 78    8   8  10
# 371  14  12  12
# 248   3   5   5
# 55    8   9  10
# 390   9   9   9
# ..   ..  ..  ..
# 364  12  11  12
# 82    7   6   6
# 114   9   9   9
# 3    15  14  15
# 18    6   5   5
#
# [79 rows x 3 columns]

# %%
from sklearn import tree

# %%
clf=tree.DecisionTreeRegressor()

# %%
clf=clf.fit(X_train,y_train)

# %%
clf.predict(X_test)
# Out:
# array([[10.,  8.,  7.],
#        [ 9., 10., 10.],
#        [ 8.,  7.,  8.],
#        [13., 15., 16.],
#        [11., 13., 13.],
#        [11., 10., 10.],
#        [15., 16., 16.],
#        [18., 18., 18.],
#        [ 7.,  9.,  8.],
#        [15., 15., 14.],
#        [17., 16., 16.],
#        [10., 12., 12.],
#        [11.,  0.,  0.],
#        [10.,  9.,  9.],
#        [ 7.,  6.,  7.],
#        [ 7.,  6.,  6.],
#        [12., 14., 15.],
#        [ 8.,  9., 10.],
#        [ 9., 10.,  0.],
#        [ 7.,  0.,  0.],
#        [10., 13., 14.],
#        [ 8.,  8.,  8.],
#        [14., 14., 14.],
#        [ 6.,  5.,  6.],
#        [16., 16., 17.],
#        [18., 18., 18.],
#        [ 9., 10.,  0.],
#        [10.,  8.,  9.],
#        [10., 10., 10.],
#        [ 7.,  9.,  8.],
#        [18., 18., 18.],
#        [18., 16., 16.],
#        [ 9., 11., 11.],
#        [14., 12., 11.],
#        [13., 15., 15.],
#        [13., 12., 12.],
#        [ 8.,  9., 10.],
#        [15., 15., 14.],
# ...

# %%
y_test
# Out:
#      G1  G2  G3
# 78    8   8  10
# 371  14  12  12
# 248   3   5   5
# 55    8   9  10
# 390   9   9   9
# ..   ..  ..  ..
# 364  12  11  12
# 82    7   6   6
# 114   9   9   9
# 3    15  14  15
# 18    6   5   5
#
# [79 rows x 3 columns]

# %%
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.multioutput import MultiOutputRegressor

# %%
clf2=make_pipeline(StandardScaler(),SVR(C=1,epsilon=0.2))
clf2=MultiOutputRegressor(clf2)

# %%
clf2.fit(X_train,y_train)
# Out:
# MultiOutputRegressor(estimator=Pipeline(steps=[('standardscaler',
#                                                 StandardScaler()),
#                                                ('svr', SVR(C=1, epsilon=0.2))]))

# %%
clf2.predict(X_test)
# Out:
# array([[ 8.36765342,  8.77265479,  9.16966905],
#        [ 9.03338875,  8.94644612,  9.19548614],
#        [11.93180888, 11.15632378, 11.03584016],
#        [11.21713011, 10.88346233, 11.94156351],
#        [10.02928305,  9.83050779, 10.12151757],
#        [ 9.85147821, 10.21218296,  9.85045236],
#        [12.66938082, 13.0924256 , 12.97382496],
#        [11.35218641, 11.41553824, 11.52924125],
#        [ 9.95804033, 10.24034993, 10.4167173 ],
#        [10.63659024, 11.15594407, 11.15714638],
#        [12.57415134, 13.20503262, 12.80168273],
#        [12.17990753, 12.05032249, 11.77961106],
#        [10.47448942, 10.76345272, 11.16131715],
#        [10.7863867 , 11.03820017, 11.11583174],
#        [11.16428426, 10.69770483, 11.13685987],
#        [ 9.54491989, 10.38682005, 10.66509063],
#        [11.46766223, 11.83156506, 11.84243321],
#        [ 9.76924299,  9.61093316, 10.35960613],
#        [11.18739815, 11.42348755, 11.85874776],
#        [10.42798674, 10.07500835, 10.43754809],
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %%
X,y=make_regression(n_features=33,n_informative=5,n_targets=3,random_state=0)

# %%
regr=RandomForestRegressor(max_depth=2,random_state=0)

# %%
regr.fit(X,y)
# Out:
# RandomForestRegressor(max_depth=2, random_state=0)

# %%
regr.predict(X_test)
# Out:
# c:\Users\shivansh uppal\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# array([[ 66.37580461, 100.82282392, 105.47724589],
#        [ 50.37633803,  53.960672  ,  54.54556473],
#        [ 98.84011244, 146.01864904, 132.34328708],
#        [ 47.52637037,  56.14633019,  51.79429394],
#        [ 85.9691186 , 131.45170069, 117.29558093],
#        [ 61.15514358,  74.00603233,  66.40979593],
#        [ 67.52438903,  80.75553415,  74.95057951],
#        [ 48.37522733,  57.1923422 ,  52.90501011],
#        [ 47.52637037,  56.14633019,  51.79429394],
#        [ 64.21739711,  77.16708868,  69.41553019],
#        [ 61.15514358,  74.00603233,  66.40979593],
#        [ 64.7429173 ,  82.35304988,  70.44278571],
#        [ 58.33224651,  72.28886158,  65.47878347],
#        [ 56.74558349,  60.71017383,  63.08634831],
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,clf.predict(X_test))
# Out:
# 27.41772151898734

# %%
mean_squared_error(y_test,model.predict(X_test))
# Out:
# 14.073698238610511

# %%
mean_squared_error(y_test,clf2.predict(X_test))
# Out:
# 13.65456699398563
