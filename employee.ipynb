# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\programming languages\project\hr_data.csv")

# %%
data
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %% [markdown]
# NUMERICAL ANALYSIS

# %%
data['number_project'].skew()
# Out:
# 0.3377056123598222

# %%
data.isnull().sum()
# Out:
# employee_id              0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# dtype: int64

# %%
data['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
data['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %% [markdown]
# LOADING EMPLOYEE DATA

# %%
dat=pd.read_excel(r"C:\programming languages\project\employee_satisfaction_evaluation.xlsx")

# %%
dat
# Out:
#        EMPLOYEE #  satisfaction_level  last_evaluation
# 0            1003                0.38             0.53
# 1            1005                0.80             0.86
# 2            1486                0.11             0.88
# 3            1038                0.72             0.87
# 4            1057                0.37             0.52
# ...           ...                 ...              ...
# 14994       87670                0.40             0.57
# 14995       87673                0.37             0.48
# 14996       87679                0.37             0.53
# 14997       87681                0.11             0.96
# 14998       87684                0.37             0.52
#
# [14999 rows x 3 columns]

# %%
dat.isnull().sum()
# Out:
# EMPLOYEE #             0
# satisfaction_level    27
# last_evaluation       27
# dtype: int64

# %% [markdown]
# MERGING TABLES

# %%
df=data.set_index('employee_id').join(dat.set_index('EMPLOYEE #'))

# %%
df=df.reset_index()

# %%
df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
#  9   satisfaction_level     14972 non-null  float64
#  10  last_evaluation        14972 non-null  float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years  satisfaction_level  \
# count   14999.000000  14999.000000           14999.000000        14972.000000
# mean        0.144610      0.238083               0.021268            0.612830
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 18            3794               2                   160                   3
# 19            1140               5                   262                   5
# 33            1230               2                   140                   3
# 53            1340               2                   132                   3
# 72           22316               2                   149                   3
# 92            1581               2                   143                   3
# 107          17376               2                   148                   3
# 120           1739               4                   158                   4
# 137           1847               2                   129                   3
# 175          32923               4                   164                   2
# 191           2160               4                   226                   6
# ...

# %%
df.fillna(df.mean(),inplace=True)
# Out:
# C:\Users\shivansh uppal\AppData\Local\Temp\ipykernel_26332\2085774198.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)

# %%
df.loc[df['employee_id']==18]
# Out:
# Empty DataFrame
# Columns: [employee_id, number_project, average_montly_hours, time_spend_company, Work_accident, left, promotion_last_5years, department, salary, satisfaction_level, last_evaluation]
# Index: []

# %%
df.drop(columns='employee_id',inplace=True)

# %%
df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# ...

# %%
data.corr()
# Out:
#                        employee_id  number_project  average_montly_hours  \
# employee_id               1.000000       -0.009225             -0.007175
# number_project           -0.009225        1.000000              0.417211
# average_montly_hours     -0.007175        0.417211              1.000000
# time_spend_company        0.104660        0.196786              0.127755
# Work_accident             0.010482       -0.004741             -0.010143
# left                     -0.099736        0.023787              0.071287
# promotion_last_5years     0.079406       -0.006064             -0.003544
#
#                        time_spend_company  Work_accident      left  \
# employee_id                      0.104660       0.010482 -0.099736
# number_project                   0.196786      -0.004741  0.023787
# average_montly_hours             0.127755      -0.010143  0.071287
# time_spend_company               1.000000       0.002120  0.144822
# ...

# %%
df.groupby('department').sum()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                     4683                248119                4256
# RandD                  3033                158030                2650
# accounting             2934                154292                2702
# hr                     2701                146828                2480
# management             2432                126787                2711
# marketing              3164                171073                3063
# product_mng            3434                180369                3135
# sales                 15634                831773               14631
# support                8479                447490                7563
# technical             10548                550793                9279
#
#              Work_accident  left  promotion_last_5years  satisfaction_level  \
# department
# IT                     164   273                      3           758.17283
# ...

# %%
df.groupby('department').mean()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                 3.816626            202.215974            3.468623
# RandD              3.853875            200.800508            3.367217
# accounting         3.825293            201.162973            3.522816
# hr                 3.654939            198.684709            3.355886
# management         3.860317            201.249206            4.303175
# marketing          3.687646            199.385781            3.569930
# product_mng        3.807095            199.965632            3.475610
# sales              3.776329            200.911353            3.534058
# support            3.803948            200.758188            3.393001
# technical          3.877941            202.497426            3.411397
#
#              Work_accident      left  promotion_last_5years  \
# department
# IT                0.133659  0.222494               0.002445
# ...

# %%
df['department'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
df['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %% [markdown]
# DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plot_corr(df,size=10):
    corr=df.corr()
    fig,ax=plt.subplots(figsize=(9,size),dpi=80)
    sns.heatmap(corr,vmax=.8,square=True)
    plt.show()

plot_corr(df)

# %%
plt.bar(x=df['left'],height=df['satisfaction_level'])
# Out:
# <BarContainer object of 14999 artists>

# %%
sns.barplot(x='left',y='satisfaction_level',data=df) #barplot of left and satisfaction level
# Out:
# <AxesSubplot:xlabel='left', ylabel='satisfaction_level'>

# %%
df.satisfaction_level.hist(bins=20) # histogram of satisfaction level
plt.show()

# %%
sns.histplot(x='satisfaction_level',data=df) # histplot is used to plot histogram
plt.show()

# %%
sns.boxplot(x='left',y='satisfaction_level',data=df) # boxplot is used to show the distribution of the data
plt.show()

# %%
sns.boxplot(x='promotion_last_5years',y='satisfaction_level',data=df) #promotion_last_5years is a categorical variable
plt.show()

# %%
sns.boxenplot(x='Work_accident',y='satisfaction_level',data=df)
# Out:
# <AxesSubplot:xlabel='Work_accident', ylabel='satisfaction_level'>

# %%
sns.pairplot(df,hue='left')
plt.show()

# %% [markdown]
# DATA MODEL FOR PREPROCESSING

# %%
y=df[['department','salary']]
y
# Out:
#       department  salary
# 0          sales     low
# 1          sales  medium
# 2          sales  medium
# 3          sales     low
# 4          sales     low
# ...          ...     ...
# 14994    support     low
# 14995    support     low
# 14996    support     low
# 14997    support     low
# 14998    support     low
#
# [14999 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

l=LabelEncoder()

k=l.fit_transform(df['salary'])

# %%
k
# Out:
# array([1, 2, 2, ..., 1, 1, 1])

# %%
df['salary_sum']=k

# %%
df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# ...

# %%
df.loc[df['salary']=='high']
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 72                  2                   149                   3
# 111                 6                   289                   4
# 189                 2                   156                   3
# 267                 2                   129                   3
# 306                 2                   149                   3
# ...               ...                   ...                 ...
# 14829               2                   148                   3
# 14868               2                   130                   3
# 14902               2                   159                   3
# 14941               2                   131                   3
# 14980               5                   238                   5
#
#        Work_accident  left  promotion_last_5years   department salary  \
# 72                 0     1                      0  product_mng   high
# ...

# %%
df.drop(['salary'],axis=1,inplace=True)

# %%
df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  \
# 0                  0     1                      0      sales
# 1                  0     1                      0      sales
# ...

# %%
z=l.fit_transform(df['department'])

# %%
z
# Out:
# array([7, 7, 7, ..., 8, 8, 8])

# %%
df['department']=z

# %%
df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years  department  \
# 0                  0     1                      0           7
# 1                  0     1                      0           7
# ...

# %%
df.loc[df['department']==1]
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 301                 3                   278                   4
# 302                 7                   250                   5
# 303                 2                   127                   3
# 304                 5                   255                   5
# 305                 2                   135                   3
# ...               ...                   ...                 ...
# 14939               4                   273                   5
# 14940               5                   285                   4
# 14941               2                   131                   3
# 14942               5                   135                   6
# 14943               5                   239                   5
#
#        Work_accident  left  promotion_last_5years  department  \
# 301                0     1                      0           1
# 302                0     1                      0           1
# ...

# %%
df.corr()
# Out:
#                        number_project  average_montly_hours  \
# number_project               1.000000              0.417211
# average_montly_hours         0.417211              1.000000
# time_spend_company           0.196786              0.127755
# Work_accident               -0.004741             -0.010143
# left                         0.023787              0.071287
# promotion_last_5years       -0.006064             -0.003544
# department                   0.009268              0.003913
# satisfaction_level          -0.143895             -0.020886
# last_evaluation              0.348776              0.339014
# salary_sum                   0.009672              0.007082
#
#                        time_spend_company  Work_accident      left  \
# number_project                   0.196786      -0.004741  0.023787
# average_montly_hours             0.127755      -0.010143  0.071287
# time_spend_company               1.000000       0.002120  0.144822
# ...

# %%
x=df.drop(['left'],axis=1)

# %%
x
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  promotion_last_5years  department  satisfaction_level  \
# 0                  0                      0           7                0.38
# ...

# %%
y=df['left']

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
y.value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
y.shape
# Out:
# (14999,)

# %% [markdown]
# SPLITTING INTO TESTING AND TRAINING

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# CUSTOM DATA PREPROCESSING

# %%
custom_data=[[10,500,10,6,4,8,0.90,0.89,2]]

# %% [markdown]
# SELECTING THE MODEL

# %%
#decision tree
from sklearn.tree import DecisionTreeClassifier

#logistic regression
from sklearn.linear_model import LogisticRegression

#random forest
from sklearn.ensemble import RandomForestClassifier

#k-nearest neighbors
from sklearn.neighbors import KNeighborsClassifier

#naive bayes
from sklearn.naive_bayes import GaussianNB

#support vector machine
from sklearn.svm import SVC

# %% [markdown]
# DECISISON TREE

# %%
dt=DecisionTreeClassifier()

dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
dt.score(X_test,y_test)
# Out:
# 0.9715555555555555

# %%
print(dt.predict(custom_data))
# Out:
# [0]
# c:\Users\shivansh uppal\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
dt.feature_importances_
# Out:
# array([9.92788562e-02, 8.62735258e-02, 1.38555631e-01, 7.62996825e-04,
#        1.74696565e-05, 1.28201236e-02, 4.99143852e-01, 1.57374256e-01,
#        5.77328869e-03])

# %%
feature_importance=pd.DataFrame(dt.feature_importances_,x.columns,columns=['importance'])
feature_importance.sort_values(by='importance',ascending=False)
# Out:
#                        importance
# satisfaction_level       0.499144
# last_evaluation          0.157374
# time_spend_company       0.138556
# number_project           0.099279
# average_montly_hours     0.086274
# department               0.012820
# salary_sum               0.005773
# Work_accident            0.000763
# promotion_last_5years    0.000017

# %% [markdown]
# LOGISTIC REGRESSION

# %%
lg=LogisticRegression(solver='newton-cg')

lg.fit(X_train,y_train)
# Out:
# LogisticRegression(solver='newton-cg')

# %%
lg.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
lg.score(X_test,y_test)
# Out:
# 0.7602222222222222

# %%
print(lg.predict(custom_data))
# Out:
# [0]
# c:\Users\shivansh uppal\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# RANDOM FOREST

# %%
rf=RandomForestClassifier(n_estimators=104)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=104)

# %%
rf.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
rf.score(X_test,y_test)
# Out:
# 0.986

# %%
print(rf.predict(custom_data))
# Out:
# [0]
# c:\Users\shivansh uppal\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# K-NEAREST NEIGHBOURS (2 NEIGHNOURS AND W/O STANDARD SCALER)

# %%
knn=KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
knn.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
knn.score(X_test,y_test)
# Out:
# 0.9417777777777778

# %%
print(knn.predict(custom_data))
# Out:
# [1]
# c:\Users\shivansh uppal\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# KNN WITH STANDARD SCALER AND NEIGHBOURS 2

# %%
#standard scaler
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler().fit(X_train)
X_train_std=sc.transform(X_train)

X_test_std=sc.transform(X_test)

# %%
knn2=KNeighborsClassifier(n_neighbors=2)
knn2.fit(X_train_std,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
knn2.predict(X_test_std)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
knn2.score(X_test_std,y_test)
# Out:
# 0.9617777777777777

# %%
from sklearn.metrics import accuracy_score

# %%
k_range=range(1,26)
scores={}
scores_list=[]

for k in k_range:
    knn2=KNeighborsClassifier(n_neighbors=k)
    knn2.fit(X_train_std,y_train)
    y_pred=knn2.predict(X_test_std)
    scores[k]=accuracy_score(y_test,y_pred)
    scores_list.append(accuracy_score(y_test,y_pred))

# %%
scores
# Out:
# {1: 0.966,
#  2: 0.9617777777777777,
#  3: 0.9551111111111111,
#  4: 0.9526666666666667,
#  5: 0.9515555555555556,
#  6: 0.9531111111111111,
#  7: 0.9493333333333334,
#  8: 0.9515555555555556,
#  9: 0.9488888888888889,
#  10: 0.9491111111111111,
#  11: 0.9468888888888889,
#  12: 0.9471111111111111,
#  13: 0.9446666666666667,
#  14: 0.946,
#  15: 0.9448888888888889,
#  16: 0.946,
#  17: 0.9435555555555556,
#  18: 0.9435555555555556,
#  19: 0.9422222222222222,
#  20: 0.9428888888888889,
#  21: 0.9413333333333334,
#  22: 0.9411111111111111,
#  23: 0.9404444444444444,
#  24: 0.9408888888888889,
#  25: 0.9395555555555556}

# %%
plt.plot(k_range,scores_list)

# %% [markdown]
# Naive Bayes

# %%
nb=GaussianNB()
nb.fit(X_train_std,y_train)
# Out:
# GaussianNB()

# %%
nb.predict(X_test_std)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
nb.score(X_test_std,y_test)
# Out:
# 0.7988888888888889

# %% [markdown]
# SUPPORT VECTOR CLASSIFIER

# %%
svc=SVC(kernel='rbf',C=10,gamma=0.1)
svc.fit(X_train_std,y_train)
# Out:
# SVC(C=10, gamma=0.1)

# %%
svc.predict(X_test_std)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
svc.score(X_test_std,y_test)
# Out:
# 0.964
